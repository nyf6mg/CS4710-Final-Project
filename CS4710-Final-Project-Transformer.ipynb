# %%
import json
import os
import pretty_midi
import glob

base_directory = '.\lmd_matched_clean'
# Specify the path to your JSON file
file_path = '.\cleaned_data.json'

# Open and read the JSON file
with open(file_path, 'r') as file:
    base_info = json.load(file)

# Iterate over each entry in the JSON data
for entry in base_info[:100]:
    # Extract the seed_genre and track_id
    seed_genre = entry['seed_genre']
    track_id = entry['track_id']

    # Construct the MIDI file path
    midi_dir = os.path.join(base_directory, seed_genre)
    pattern = os.path.join(midi_dir, f"{track_id}*.mid")
    matching_files = glob.glob(pattern)

    if matching_files:
        # Load the first matching file
        midi_file_path = matching_files[0]
        try:
            # Load the MIDI file using pretty_midi
            midi = pretty_midi.PrettyMIDI(midi_file_path)
            print(f"Successfully loaded: {midi_file_path}")
            for instrument in midi.instruments:
                print(f"Instrument: {instrument.name}, Program: {instrument.program}, Is Drum: {instrument.is_drum}")
        except Exception as e:
            print(f"Error loading {midi_file_path}: {e}")
    else:
        print(f"No matching files found for track_id: {track_id} in {midi_dir}")
# Out:
# No matching files found for track_id: TRAAAAK128F9318786 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAAAAW128F429D538 in .\lmd_matched_clean\Hip-Hop
# No matching files found for track_id: TRAAABD128F429CF47 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAAAED128E0783FAB in .\lmd_matched_clean\Jazz
# No matching files found for track_id: TRAAAEF128F4273421 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAAAFD128F92F423A in .\lmd_matched_clean\Rock
# Successfully loaded: .\lmd_matched_clean\Pop\TRAAAGR128F425B14B_1d9d16a9da90c090809c153754823c2b_Pop.mid
# Instrument: main synth          , Program: 62, Is Drum: False
# Instrument: echo synth          , Program: 62, Is Drum: False
# Instrument: main strings h      , Program: 48, Is Drum: False
# Instrument: main strings m      , Program: 48, Is Drum: False
# Instrument: main strings l      , Program: 48, Is Drum: False
# Instrument: main bass           , Program: 33, Is Drum: False
# Instrument: drums + fills       , Program: 0, Is Drum: True
# Instrument: xtras               , Program: 14, Is Drum: False
# Instrument: harpsichord         , Program: 6, Is Drum: False
# Instrument: verse vibe h        , Program: 19, Is Drum: False
# Instrument: verse vibe m        , Program: 19, Is Drum: False
# Instrument: verse vibe l        , Program: 19, Is Drum: False
# Instrument: verse piano         , Program: 1, Is Drum: False
# Instrument: verse xtra          , Program: 64, Is Drum: False
# Instrument: end string h        , Program: 48, Is Drum: False
# Instrument: voice               , Program: 1, Is Drum: False
# Instrument: orchestra hit       , Program: 55, Is Drum: False
# No matching files found for track_id: TRAAAHD128F42635A5 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAAAIC128F14A5138 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAAARJ128F9320760 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAAAUR128F428B1FA in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAAAYL128F4271A5B in .\lmd_matched_clean\Rock
# Successfully loaded: .\lmd_matched_clean\Pop\TRAAAZF12903CCCF6B_05f21994c71a5f881e64f45c8d706165_Pop.mid
# Instrument: POLYSYNTH, Program: 90, Is Drum: False
# Instrument: FINGERDBAS, Program: 33, Is Drum: False
# Instrument: CLEAN GTR , Program: 27, Is Drum: False
# Instrument: MUTED GTR, Program: 28, Is Drum: False
# Instrument: SWEEP PAD, Program: 95, Is Drum: False
# Instrument: DRUMS, Program: 0, Is Drum: True
# No matching files found for track_id: TRAABBY128F930C3B5 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAABEV12903CC53A4 in .\lmd_matched_clean\Electronic
# No matching files found for track_id: TRAABHC128F933A3F8 in .\lmd_matched_clean\Country
# No matching files found for track_id: TRAABHO12903D08576 in .\lmd_matched_clean\Jazz
# No matching files found for track_id: TRAABIG128F9356C56 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAABIL128F92C1D88 in .\lmd_matched_clean\Pop
# No matching files found for track_id: TRAABIX128F92D6F94 in .\lmd_matched_clean\Electronic
# No matching files found for track_id: TRAABJS128F9325C99 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAABJV128F1460C49 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAABLR128F423B7E3 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAABOA128F933684A in .\lmd_matched_clean\Reggae
# No matching files found for track_id: TRAABPG128F14774DD in .\lmd_matched_clean\Pop
# No matching files found for track_id: TRAABPQ128F428F0B0 in .\lmd_matched_clean\Pop
# No matching files found for track_id: TRAABRU12903D06D56 in .\lmd_matched_clean\Dance
# Successfully loaded: .\lmd_matched_clean\Rock\TRAABVM128F92CA9DC_0dd4d2b9fbcf96a0fa363a1918255e58_Rock.mid
# Instrument: , Program: 30, Is Drum: False
# Instrument: , Program: 24, Is Drum: False
# Instrument: , Program: 36, Is Drum: False
# Instrument: , Program: 12, Is Drum: False
# Instrument: , Program: 54, Is Drum: False
# Instrument: Percussão, Program: 24, Is Drum: True
# No matching files found for track_id: TRAABWH128F427ABE8 in .\lmd_matched_clean\Jazz
# No matching files found for track_id: TRAABXA128F9326351 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAACBV128F93354B6 in .\lmd_matched_clean\R&B
# No matching files found for track_id: TRAACER128F4290F96 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAACIE128F428495B in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAACIW12903CC0F6D in .\lmd_matched_clean\Electronic
# No matching files found for track_id: TRAACKI128F427F03B in .\lmd_matched_clean\Dance
# No matching files found for track_id: TRAACKM12903CE5BE9 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAACLG128F4276511 in .\lmd_matched_clean\Electronic
# No matching files found for track_id: TRAACLP128F9314378 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAACMJ128F930C704 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAACNS128F14A2DF5 in .\lmd_matched_clean\Jazz
# No matching files found for track_id: TRAACOE128F9352355 in .\lmd_matched_clean\Country
# No matching files found for track_id: TRAACPE128F421C1B9 in .\lmd_matched_clean\R&B
# No matching files found for track_id: TRAACPH12903CF5F14 in .\lmd_matched_clean\Rock
# Successfully loaded: .\lmd_matched_clean\Pop\TRAACQE12903CC706C_1ee7c9ad5f18b2659789d9608c951ca5_Pop.mid
# Instrument: CLOSER TO ME                    ;Words and music by John Spinks, Program: 0, Is Drum: True
# Instrument: CLOSER TO ME                    ;Words and music by John Spinks, Program: 35, Is Drum: False
# Instrument: CLOSER TO ME                    ;Words and music by John Spinks, Program: 29, Is Drum: False
# Instrument: CLOSER TO ME                    ;Words and music by John Spinks, Program: 84, Is Drum: False
# Instrument: CLOSER TO ME                    ;Words and music by John Spinks, Program: 17, Is Drum: False
# Instrument: CLOSER TO ME                    ;Words and music by John Spinks, Program: 25, Is Drum: False
# Instrument: CLOSER TO ME                    ;Words and music by John Spinks, Program: 25, Is Drum: False
# Instrument: CLOSER TO ME                    ;Words and music by John Spinks, Program: 28, Is Drum: False
# Instrument: CLOSER TO ME                    ;Words and music by John Spinks, Program: 62, Is Drum: False
# Instrument: CLOSER TO ME                    ;Words and music by John Spinks, Program: 73, Is Drum: False
# Instrument: CLOSER TO ME                    ;Words and music by John Spinks, Program: 103, Is Drum: False
# Instrument: CLOSER TO ME                    ;Words and music by John Spinks, Program: 29, Is Drum: False
# Instrument: CLOSER TO ME                    ;Words and music by John Spinks, Program: 29, Is Drum: False
# Instrument: CLOSER TO ME                    ;Words and music by John Spinks, Program: 7, Is Drum: False
# No matching files found for track_id: TRAACSL128F93462F4 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAACTB12903CAAF15 in .\lmd_matched_clean\Country
# No matching files found for track_id: TRAACZK128F4243829 in .\lmd_matched_clean\World
# No matching files found for track_id: TRAACZN128F93236B1 in .\lmd_matched_clean\Hip-Hop
# No matching files found for track_id: TRAACZR12903CDD291 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAADAD128F9336553 in .\lmd_matched_clean\Reggae
# No matching files found for track_id: TRAADBN128F932D00A in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAADCQ128F932EC14 in .\lmd_matched_clean\Pop
# No matching files found for track_id: TRAADEB128F9335868 in .\lmd_matched_clean\Hip-Hop
# Successfully loaded: .\lmd_matched_clean\Folk\TRAADKW128E079503A_3797e9b9a101c110b7375c74dd4c70b1_Folk.mid
# Instrument: Fast Car - Tracy Chapman, Program: 73, Is Drum: False
# Instrument: , Program: 25, Is Drum: False
# Instrument: , Program: 34, Is Drum: False
# Instrument: , Program: 26, Is Drum: False
# Instrument: , Program: 33, Is Drum: False
# Instrument: , Program: 24, Is Drum: False
# Instrument: , Program: 74, Is Drum: False
# Instrument: Tracy Chapman - Fast Car, Program: 117, Is Drum: False
# Instrument: , Program: 0, Is Drum: True
# No matching files found for track_id: TRAADLH12903CA70EE in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAADLX128F1469250 in .\lmd_matched_clean\Folk
# No matching files found for track_id: TRAADMH128F9343E59 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAADNA128F9331246 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAADNN128F42B1D94 in .\lmd_matched_clean\Pop
# No matching files found for track_id: TRAADQL128F427D281 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAADQW128F427CE68 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAADQX128F422B4CF in .\lmd_matched_clean\Electronic
# No matching files found for track_id: TRAADSV128F42BC36A in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAADUU128E0791BF5 in .\lmd_matched_clean\Folk
# No matching files found for track_id: TRAADUW128F931EF47 in .\lmd_matched_clean\Latin
# No matching files found for track_id: TRAADVH128EF34DE7A in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAADVO128E07999E9 in .\lmd_matched_clean\Jazz
# No matching files found for track_id: TRAADXK12903CFAE92 in .\lmd_matched_clean\Country
# No matching files found for track_id: TRAADYB128F92D7E73 in .\lmd_matched_clean\Jazz
# No matching files found for track_id: TRAADYI128E078FB38 in .\lmd_matched_clean\Hip-Hop
# No matching files found for track_id: TRAAEAM128F934B199 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAAECM128F9321318 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAAEDF128F930CC0F in .\lmd_matched_clean\Jazz
# No matching files found for track_id: TRAAEEO128F4288E88 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAAEHW128F9344FD3 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAAEIY128F933A659 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAAEJQ128F92C484E in .\lmd_matched_clean\R&B
# No matching files found for track_id: TRAAEMJ128F425A917 in .\lmd_matched_clean\Pop
# No matching files found for track_id: TRAAENC128F1451DE9 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAAENM128EF33EDAA in .\lmd_matched_clean\Pop
# No matching files found for track_id: TRAAEPG128F429139A in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAAERZ128F1496921 in .\lmd_matched_clean\Reggae
# No matching files found for track_id: TRAAEWC128F427D19B in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAAEWG128F930B3A4 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAAFBP128F92D4546 in .\lmd_matched_clean\Reggae
# No matching files found for track_id: TRAAFCS128F92F9522 in .\lmd_matched_clean\Pop
# No matching files found for track_id: TRAAFDF128F42494A2 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAAFDR128F932937A in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAAFEU128E078581C in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAAFGQ128F427D884 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAAFHY12903CB3BB3 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAAFJW128F428A424 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAAFML128F1451AF1 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAAFMS128F933AB23 in .\lmd_matched_clean\Latin
# Successfully loaded: .\lmd_matched_clean\Pop\TRAAFMT128F429DB58_0a4f2051b572ebe007647fcab0114dd8_Pop.mid
# Instrument: Vocals, Program: 40, Is Drum: False
# Instrument: Acoustic 1, Program: 25, Is Drum: False
# Instrument: Acoustic 2, Program: 27, Is Drum: False
# Instrument: Piano, Program: 2, Is Drum: False
# Instrument: Distortion 1, Program: 30, Is Drum: False
# Instrument: Distortion 2, Program: 29, Is Drum: False
# Instrument: Bass, Program: 33, Is Drum: False
# Instrument: Bass, Program: 33, Is Drum: False
# Instrument: Drums, Program: 0, Is Drum: True
# No matching files found for track_id: TRAAFOH128E078BD7E in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAAFOY128F146CC17 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAAFQF128F92F8770 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAAFRM128F9320F58 in .\lmd_matched_clean\Rock
# No matching files found for track_id: TRAAFRU128F9339158 in .\lmd_matched_clean\World
